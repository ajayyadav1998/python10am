# %%
pwd
# Out:
# 'E:\\A\\hrishwa'

# %%
ls
# Out:
#  Volume in drive E is Ajju
#  Volume Serial Number is 52D5-E649
#
#  Directory of E:\A\hrishwa
#
# 10/22/2019  10:31 AM    <DIR>          .
# 10/22/2019  10:31 AM    <DIR>          ..
# 10/22/2019  10:28 AM    <DIR>          .ipynb_checkpoints
# 09/22/2019  01:29 PM            15,691 Basics of python.ipynb
# 10/03/2019  10:41 AM             7,023 Conditional_statement.ipynb
# 10/22/2019  10:31 AM               877 File handling in python.ipynb
# 10/18/2019  11:30 AM            50,981 Function in python.ipynb
# 09/30/2019  11:34 AM             1,434 GIT_COMMANDS.txt
# 09/22/2019  01:08 PM                30 hello.txt
# 10/10/2019  12:12 PM            13,077 list comprehension.ipynb
# 10/17/2019  10:30 AM         2,897,705 Loops in python.ipynb
# 09/26/2019  11:15 AM            27,539 operators in python.ipynb
# 10/14/2019  11:31 AM             2,726 priti ma'am loop class.ipynb
# 10/21/2019  11:17 AM                12 README.md
# 10/18/2019  12:03 PM             3,672 Untitled.ipynb
# ...

# %%
file = open('hello.txt')

# %%
file.read()
# Out:
# 'hello to the world of python\n'

# %%
file.close()

# %%
file = open('ajay.txt','w')

# %%
print(dir(file))
# Out:
# ['_CHUNK_SIZE', '__class__', '__del__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_checkClosed', '_checkReadable', '_checkSeekable', '_checkWritable', '_finalizing', 'buffer', 'close', 'closed', 'detach', 'encoding', 'errors', 'fileno', 'flush', 'isatty', 'line_buffering', 'mode', 'name', 'newlines', 'read', 'readable', 'readline', 'readlines', 'reconfigure', 'seek', 'seekable', 'tell', 'truncate', 'writable', 'write', 'write_through', 'writelines']

# %%
file
# Out:
# <_io.TextIOWrapper name='ajay.txt' mode='w' encoding='cp1252'>

# %%
file.writable()
# Out:
# True

# %%
print('apple is good for health and usage too',file=file)
file.close()

# %%
f = open('ajay.txt')

# %%
f.read()
# Out:
# 'apple is good for health and usage too\n'

# %%
f.read()
# Out:
# ''

# %%
f.readable()
# Out:
# True

# %%
f.read()
# Out:
# ''

# %%
f.tell()
# Out:
# 40

# %%
f.seek(0)
# Out:
# 0

# %%
data = f.read()

# %%
f.close()
data
# Out:
# 'apple is good for health and usage too\n'

# %%
data
# Out:
# 'apple is good for health and usage too\n'

# %%
data
# Out:
# 'apple is good for health and usage too\n'

# %%
file = open('ajay.txt','w')
file.write('this is the week of diwali which is famous indian festival\n')
file.close()

# %%
file = open('ajay.txt')
data= file.read()
file.close()

# %%
data
# Out:
# 'this is the week of diwali which is famous indian festival\n'

# %%
file = open('ajay.txt','a')
file.write('diwali is full of enjoyment with lots of fun')
file.close()

# %%
file = open('ajay.txt')

# %%
file.readline()
# Out:
# 'this is the week of diwali which is famous indian festival\n'

# %%
file.seek(0)
# Out:
# 0

# %%
data = file.readlines()
file.close()

# %%
data
# Out:
# ['this is the week of diwali which is famous indian festival\n',
#  'diwali is full of enjoyment with lots of fun']

# %%
d = []
for var in data:
    d.append(var.rstrip())
    
print(d)
# Out:
# ['this is the week of diwali which is famous indian festival', 'diwali is full of enjoyment with lots of fun']

# %%
file = open('table.txt')
data = file.read()
file.close()

# %%
data
# Out:
# '12\t78\t89\t89\n98\t98\t98\t98\n67\t68\t90\t89\n87\t98\t78\t98\n98\t87\t67\t76\n56\t67\t87\t76\n45\t76\t98\t87\n'

# %%
toda = data.split('\n')
toda
# Out:
# ['12\t78\t89\t89',
#  '98\t98\t98\t98',
#  '67\t68\t90\t89',
#  '87\t98\t78\t98',
#  '98\t87\t67\t76',
#  '56\t67\t87\t76',
#  '45\t76\t98\t87',
#  '']

# %%
toda.pop()
# Out:
# ''

# %%
toda
# Out:
# ['12\t78\t89\t89',
#  '98\t98\t98\t98',
#  '67\t68\t90\t89',
#  '87\t98\t78\t98',
#  '98\t87\t67\t76',
#  '56\t67\t87\t76',
#  '45\t76\t98\t87']

# %%
toda = list(map(lambda string : string.split(),toda))
toda
# Out:
# [['12', '78', '89', '89'],
#  ['98', '98', '98', '98'],
#  ['67', '68', '90', '89'],
#  ['87', '98', '78', '98'],
#  ['98', '87', '67', '76'],
#  ['56', '67', '87', '76'],
#  ['45', '76', '98', '87']]

# %%
num = []

for var in toda:
    num.extend(var)

# %%
print(num)
# Out:
# ['12', '78', '89', '89', '98', '98', '98', '98', '67', '68', '90', '89', '87', '98', '78', '98', '98', '87', '67', '76', '56', '67', '87', '76', '45', '76', '98', '87']

# %%
from functools import reduce

# %%
mys = reduce(lambda x,y : int(x)+int(y),num)
mys
# Out:
# 2255

# %%
n = []

for var in num:
    n.append(int(var))

# %%
n
# Out:
# [12,
#  78,
#  89,
#  89,
#  98,
#  98,
#  98,
#  98,
#  67,
#  68,
#  90,
#  89,
#  87,
#  98,
#  78,
#  98,
#  98,
#  87,
#  67,
#  76,
#  56,
#  67,
#  87,
#  76,
#  45,
#  76,
#  98,
#  87]

# %%
ls
# Out:
#  Volume in drive E is Ajju
#  Volume Serial Number is 52D5-E649
#
#  Directory of E:\A\hrishwa
#
# 10/22/2019  11:00 AM    <DIR>          .
# 10/22/2019  11:00 AM    <DIR>          ..
# 10/22/2019  10:28 AM    <DIR>          .ipynb_checkpoints
# 10/22/2019  10:44 AM               104 ajay.txt
# 09/22/2019  01:29 PM            15,691 Basics of python.ipynb
# 10/03/2019  10:41 AM             7,023 Conditional_statement.ipynb
# 10/22/2019  10:59 AM            15,754 File handling in python.ipynb
# 10/18/2019  11:30 AM            50,981 Function in python.ipynb
# 09/30/2019  11:34 AM             1,434 GIT_COMMANDS.txt
# 09/22/2019  01:08 PM                30 hello.txt
# 10/10/2019  12:12 PM            13,077 list comprehension.ipynb
# 10/17/2019  10:30 AM         2,897,705 Loops in python.ipynb
# 09/26/2019  11:15 AM            27,539 operators in python.ipynb
# 10/22/2019  11:00 AM            30,156 photo.jpg
# 10/14/2019  11:31 AM             2,726 priti ma'am loop class.ipynb
# ...

# %%
file = open('photo.jpg','rb')
data = file.read()
file.close()

# %%
len(data)
# Out:
# 30156

# %%
f = open('2109.jpg','rb')

# %%
d = f.read()
len(d)
# Out:
# 151996

# %%
data[:100]
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00H\x00H\x00\x00\xff\xe2\x03\xbcICC_PROFILE\x00\x01\x01\x00\x00\x03\xacKCMS\x02\x10\x00\x00mntrRGB XYZ \x07\xce\x00\x0c\x00\x01\x00\x12\x00:\x00\x15acspMSFT\x00\x00\x00\x00KODAROMM\x00\x00\x00\x00\x00\x00'

# %%
k = open('C:/Users/Ajay/Desktop/samp.jpg','wb')
k.write(data)
k.close()

# %%
from PIL import Image

# %%
g = Image.open('samp.jpg')

# %%
g
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x667 at 0x17372DA8C88>

# %%
eve = [var for var in range(100) if var %2==0 or var % 5 ==0 ]

# %%
print(eve)
# Out:
# [0, 2, 4, 5, 6, 8, 10, 12, 14, 15, 16, 18, 20, 22, 24, 25, 26, 28, 30, 32, 34, 35, 36, 38, 40, 42, 44, 45, 46, 48, 50, 52, 54, 55, 56, 58, 60, 62, 64, 65, 66, 68, 70, 72, 74, 75, 76, 78, 80, 82, 84, 85, 86, 88, 90, 92, 94, 95, 96, 98]
